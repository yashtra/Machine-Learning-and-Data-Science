# %%
# %matplotlib inline
import numpy as np
import pandas as pd

df = pd.read_csv("Data.csv")
df.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount
# 0      0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2      2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4      4       Bengaluru, India   5-May-15       Gold    Bills      F  171574

# %%
df.shape
# Out:
# (26052, 7)

# %%
df.head(50)
# Out:
#     index                   City       Date  Card Type Exp Type Gender  Amount
# 0       0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1       1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2       2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3       3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4       4       Bengaluru, India   5-May-15       Gold    Bills      F  171574
# 5       5           Delhi, India   8-Sep-14     Silver    Bills      F  100036
# 6       6           Delhi, India  24-Feb-15       Gold    Bills      F  143250
# 7       7  Greater Mumbai, India  26-Jun-14   Platinum    Bills      F  150980
# 8       8           Delhi, India  28-Mar-14     Silver    Bills      F  192247
# 9       9           Delhi, India   1-Sep-14   Platinum    Bills      F   67932
# 10     10           Delhi, India  22-Jun-14   Platinum    Bills      F  280061
# ...

# %%
start_index = 1
end_index = 12000
df_sliced = df.iloc[start_index:end_index + 1]

grouped= df_sliced.groupby(['City', 'Card Type']).size().unstack(fill_value=0)
# Plotting
grouped.plot(kind='bar', stacked=True)
plt.title('Distribution of types of cards w.r.t cities')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='types of cards')
plt.show()

# %%
import seaborn as sns

start_index = 1
end_index = 9000
df_sliced = df.iloc[start_index:end_index + 1]

grouped = df_sliced.groupby(['Greater Mumbai, India', 'Exp Type', 'Gender'])['Amount'].sum().unstack(fill_value=0)

# Plotting using seaborn
sns.set(style="whitegrid")
grouped.plot(kind='bar', stacked=True)
plt.title('Expenditure by Gender in Different Cities')
plt.xlabel('City - Expenditure Type')
plt.ylabel('Amount')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Gender', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df.sort_values(['Date'])
# Out:
#        index                 City      Date  Card Type       Exp Type Gender  \
# 24582  24582       Chennai, India  1-Apr-14   Platinum  Entertainment      F
# 16742  16742  Wadgaon Road, India  1-Apr-14       Gold           Food      M
# 4305    4305     Bengaluru, India  1-Apr-14   Platinum          Bills      F
# 20368  20368        Jaipur, India  1-Apr-14   Platinum  Entertainment      M
# 15309  15309         Nokha, India  1-Apr-14  Signature          Bills      M
# ...      ...                  ...       ...        ...            ...    ...
# 12607  12607     Bengaluru, India  9-Sep-14       Gold           Food      M
# 3136    3136         Delhi, India  9-Sep-14   Platinum           Food      F
# 17742  17742         Udupi, India  9-Sep-14       Gold  Entertainment      M
# 7435    7435         Delhi, India  9-Sep-14  Signature           Food      M
# 15194  15194  Rajagangapur, India  9-Sep-14  Signature           Food      M
#
#        Amount
# 24582   93038
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['cap-diameter'], df['family'], color='blue', alpha=0.5)
plt.title('Cap-diameter vs Family')
plt.xlabel('cap-diameter')
plt.ylabel('family')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()
